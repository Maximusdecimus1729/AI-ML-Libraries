# %%
import matplotlib.pyplot as plt
import numpy as np
import random

arr = np.random.randint(10,60,(50))
print(arr)
# Out:
# [40 34 28 54 45 42 11 29 48 49 57 22 23 49 15 46 53 30 24 12 42 37 36 18
#  51 34 38 59 25 44 38 44 17 11 18 38 27 46 30 50 13 51 29 41 57 26 48 24
#  50 49]

# %%
no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no, "auto", (0,200),  edgecolor = "r" )
#bins = x_axis) #bins parametr
#cumultaive parameter 

plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.show()
# Out:
# C:\Users\gorav\AppData\Local\Temp\ipykernel_14932\3018988711.py:7: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(no, "auto", (0,200),  edgecolor = "r" )

# %% [markdown]
# bins paramter

# %%
no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no ,bins = x_axis,  edgecolor = "r" )  #bins parametr


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.show()

# %% [markdown]
# cumultaive parameter

# %%
no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no, cumulative = -1, edgecolor = "r" )  


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.show()

# %% [markdown]
# bottom parametr

# %%
no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no, bottom = 20, edgecolor = "r" )   #y-axis starts with 20 (bottom)


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.show()

# %% [markdown]
# align paramter

# %%
no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no, align = "left", edgecolor = "r" )   #to align x-axis elemnets 


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.show()

# %% [markdown]
# Types of histogram

# %%
no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no, histtype = "step", edgecolor = "r" )  #many  ore types


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.show()

# %% [markdown]
# orientation

# %%
no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no, orientation = "horizontal", edgecolor = "r" )  


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.show()

# %% [markdown]
# others

# %%
no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no ,bins = x_axis,  edgecolor = "r", rwidth  = 0.8, align = "left")  #bins parametr


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.show()

# %%
#log parameter

no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no ,bins = x_axis,  edgecolor = "r", rwidth  = 0.8, align = "left", log = "true") 


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.show()

# %% [markdown]
# Axvline

# %%
no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no ,bins = x_axis,  edgecolor = "r", rwidth  = 0.8, align = "left", label = "python")  


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.axvline(25, color ="r", label = "line")

plt.legend()
plt.show()

# %% [markdown]
# Grid

# %%
no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no ,bins = x_axis,  edgecolor = "r", rwidth  = 0.8, align = "left", label = "python")  


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.axvline(25, color ="r", label = "line")

plt.legend()
plt.grid()
plt.show()
