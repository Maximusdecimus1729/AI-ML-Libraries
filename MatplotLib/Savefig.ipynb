# %% [markdown]
# Save the graph

# %%
import matplotlib.pyplot as plt

no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no ,bins = x_axis,  edgecolor = "r", rwidth  = 0.8, align = "left", log = "true") 


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.savefig("Histo")

plt.show()

# %% [markdown]
# Save with different parameters

# %%
import matplotlib.pyplot as plt

no = [57,35,51,56,18,46,29,27,17,33,10,24,43,36,33,13,56,26,49,36,11,25,43,29
,12,15,48,57,20,46,46,41,24,35,11,35,12,14,14,31,21,51,31,25,48,43,55,26
,21,35]

x_axis  = [ 10,15,20,25,30,35,40,45,50]

plt.hist(no ,bins = x_axis,  edgecolor = "r", rwidth  = 0.8, align = "left", log = "true") 


plt.title("Histogram")
plt.xlabel("X-axis")
plt.ylabel("y-axis")

plt.savefig("Histo_box_inches", dpi = 2000, facecolor = "y", bbox_inches = "tight")

plt.show()
