# %%
#COPY VS VIEW

import numpy as np

var = np.array([1,2,3,3,4])

co = var.copy()

var[1] = 20

print("var : ",var)
print("copy : ",co)
# Out:
# var :  [ 1 20  3  3  4]
# copy :  [1 2 3 3 4]

# %%
import numpy as np
var = np.array([1,2,3,3,4])

vi = var.view()

var[1] = 20

print("var : ",var)
print("view : ",vi)
# Out:
# var :  [ 1 20  3  3  4]
# view :  [ 1 20  3  3  4]
